# %% [markdown]
# ## 1. Conexión del entorno de trabajo con Google Drive
#
# Para garantizar la persistencia de los archivos del proyecto entre sesiones de Google Colab, se realiza la conexión con Google Drive. Esto permite almacenar el repositorio y los datos de forma segura y reutilizable durante todo el desarrollo del análisis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Clonación del repositorio del proyecto desde GitHub
#
# Se clona el repositorio del proyecto desde GitHub en el entorno de Google Drive para disponer de una copia local que permita el desarrollo del análisis y el control de versiones.

# %%
# %cd /content/drive/MyDrive/
# !git clone https://github.com/SantiAp11/churn_TelecomX.git
# Out:
# /content/drive/MyDrive
# Cloning into 'churn_TelecomX'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %% [markdown]
# ## 3. Acceso al repositorio del proyecto
#
# Una vez clonado el repositorio desde GitHub, se accede al directorio del proyecto para comenzar a trabajar sobre su contenido y ejecutar las siguientes tareas de configuración y análisis.

# %%
# %cd churn_TelecomX
# Out:
# [Errno 2] No such file or directory: 'churn_TelecomX'
# /content/drive/MyDrive/churn_TelecomX

# %% [markdown]
# ## 4. Creación de la estructura inicial del proyecto
#
# Se define la estructura básica de carpetas del proyecto con el fin de organizar los datos, los notebooks y los resultados del análisis desde el inicio, facilitando el mantenimiento y la escalabilidad del trabajo.

# %%
# !mkdir data notebooks src outputs
# !mkdir data/raw data/processed
# !mkdir outputs/figures outputs/tables

# %%
# !touch data/.gitkeep
# !touch data/raw/.gitkeep
# !touch data/processed/.gitkeep
# !touch notebooks/.gitkeep
# !touch src/.gitkeep
# !touch outputs/.gitkeep
# !touch outputs/figures/.gitkeep
# !touch outputs/tables/.gitkeep

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	data/
# 	notebooks/
# 	outputs/
# 	src/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add data notebooks outputs src

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   data/.gitkeep
# 	new file:   data/processed/.gitkeep
# 	new file:   data/raw/.gitkeep
# 	new file:   notebooks/.gitkeep
# 	new file:   outputs/.gitkeep
# 	new file:   outputs/figures/.gitkeep
# 	new file:   outputs/tables/.gitkeep
# 	new file:   src/.gitkeep

# %%
# !git config --global user.name "Santiago Aparicio"
# !git config --global user.email "santiagoaparicioperez674@gmail.com"
# !git config --global --list
# Out:
# user.name=Santiago Aparicio
# user.email=santiagoaparicioperez674@gmail.com

# %%
# !git commit -m "Estructura inicial del proyecto de análisis de churn"
# !git push origin main
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# remote: Permission to SantiAp11/churn_TelecomX.git denied to SantiAp11.
# fatal: unable to access 'https://github.com/SantiAp11/churn_TelecomX.git/': The requested URL returned error: 403
